# %%
import pandas as pd
import numpy as np

# %%
def load_data(filename):
    df = pd.read_csv(filename,sep=',',header=96)
    df = df.dropna()
    df = df.rename(columns={"foo": "bar"})
    return df


df= load_data('exoplanete.csv')
df
# Out:
#                 pl_name        hostname  default_flag  sy_snum  sy_pnum  \
# 476    EPIC 249893012 b  EPIC 249893012             1        1        3
# 477    EPIC 249893012 c  EPIC 249893012             1        1        3
# 478    EPIC 249893012 d  EPIC 249893012             1        1        3
# 607            GJ 367 b          GJ 367             1        1        3
# 1345          HATS-17 b         HATS-17             1        1        1
# ...                 ...             ...           ...      ...      ...
# 33631         TOI-836 b         TOI-836             1        1        2
# 33633         TOI-836 c         TOI-836             1        1        2
# 33647         TOI-908 b         TOI-908             1        1        1
# 34258        WASP-193 b        WASP-193             1        1        1
# 34980            XO-7 b            XO-7             1        1        1
#
#       discoverymethod  disc_year  \
# 476           Transit       2020
# 477           Transit       2020
# 478           Transit       2020
# 607           Transit       2021
# 1345          Transit       2016
# ...               ...        ...
# 33631         Transit       2023
# 33633         Transit       2023
# 33647         Transit       2023
# 34258         Transit       2023
# 34980         Transit       2019
#
#                                       disc_facility              soltype  \
# 476                                              K2  Published Confirmed
# 477                                              K2  Published Confirmed
# 478                                              K2  Published Confirmed
# 607    Transiting Exoplanet Survey Satellite (TESS)  Published Confirmed
# 1345                                       HATSouth  Published Confirmed
# ...                                             ...                  ...
# 33631  Transiting Exoplanet Survey Satellite (TESS)  Published Confirmed
# 33633  Transiting Exoplanet Survey Satellite (TESS)  Published Confirmed
# 33647  Transiting Exoplanet Survey Satellite (TESS)  Published Confirmed
# 34258                                    WASP-South  Published Confirmed
# 34980                                            XO  Published Confirmed
#
#        pl_controv_flag  ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  \
# 476                  0  ...      -0.022    9.714        0.023       -0.023
# 477                  0  ...      -0.022    9.714        0.023       -0.023
# 478                  0  ...      -0.022    9.714        0.023       -0.023
# 607                  0  ...      -0.044    5.780        0.020       -0.020
# 1345                 0  ...      -0.057   10.698        0.021       -0.021
# ...                ...  ...         ...      ...          ...          ...
# 33631                0  ...      -0.030    6.804        0.018       -0.018
# 33633                0  ...      -0.030    6.804        0.018       -0.018
# 33647                0  ...      -0.012    9.637        0.021       -0.021
# 34258                0  ...      -0.023   10.745        0.035       -0.035
# 34980                0  ...      -0.006    9.241        0.024       -0.024
#
#        sy_gaiamag  sy_gaiamagerr1  sy_gaiamagerr2   rowupdate  pl_pubdate  \
# 476      11.40190        0.000495       -0.000495  2020-02-06     2020-04
# 477      11.40190        0.000495       -0.000495  2020-02-06     2020-04
# 478      11.40190        0.000495       -0.000495  2020-02-06     2020-04
# 607       9.15159        0.000650       -0.000650  2023-08-10     2023-07
# 1345     12.21790        0.000249       -0.000249  2016-09-14     2016-04
# ...           ...             ...             ...         ...         ...
# 33631     9.40475        0.000443       -0.000443  2023-02-25     2023-02
# 33633     9.40475        0.000443       -0.000443  2023-02-25     2023-02
# 33647    11.10610        0.000404       -0.000404  2023-07-10     2023-06
# 34258    12.04210        0.000261       -0.000261  2023-07-26     2023-07
# 34980    10.45750        0.000449       -0.000449  2020-01-13     2020-02
#
#        releasedate
# 476     2020-02-13
# 477     2020-02-13
# 478     2020-02-13
# 607     2023-08-10
# 1345    2016-09-15
# ...            ...
# 33631   2023-02-25
# 33633   2023-02-25
# 33647   2023-07-10
# 34258   2023-07-26
# 34980   2020-01-16
#
# [80 rows x 92 columns]

# %%
df = pd.read_csv('exoplanete.csv',sep=',',header=96)
df
# Out:
#          pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0       11 Com b   11 Com             0        2        1  Radial Velocity
# 1       11 Com b   11 Com             0        2        1  Radial Velocity
# 2       11 Com b   11 Com             1        2        1  Radial Velocity
# 3       11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4       11 UMi b   11 UMi             0        1        1  Radial Velocity
# ...          ...      ...           ...      ...      ...              ...
# 35110  ups And d  ups And             0        2        3  Radial Velocity
# 35111  ups Leo b  ups Leo             1        1        1  Radial Velocity
# 35112   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 35113   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 35114   xi Aql b   xi Aql             1        1        1  Radial Velocity
#
#        disc_year                           disc_facility              soltype  \
# 0           2007                        Xinglong Station  Published Confirmed
# 1           2007                        Xinglong Station  Published Confirmed
# 2           2007                        Xinglong Station  Published Confirmed
# 3           2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# 4           2009  Thueringer Landessternwarte Tautenburg  Published Confirmed
# ...          ...                                     ...                  ...
# 35110       1999                  Multiple Observatories  Published Confirmed
# 35111       2021       Okayama Astrophysical Observatory  Published Confirmed
# 35112       2007       Okayama Astrophysical Observatory  Published Confirmed
# 35113       2007       Okayama Astrophysical Observatory  Published Confirmed
# 35114       2007       Okayama Astrophysical Observatory  Published Confirmed
#
#        pl_controv_flag  ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  \
# 0                    0  ...      -0.023    2.282        0.346       -0.346
# 1                    0  ...      -0.023    2.282        0.346       -0.346
# 2                    0  ...      -0.023    2.282        0.346       -0.346
# 3                    0  ...      -0.005    1.939        0.270       -0.270
# 4                    0  ...      -0.005    1.939        0.270       -0.270
# ...                ...  ...         ...      ...          ...          ...
# 35110                0  ...      -0.023    2.859        0.274       -0.274
# 35111                0  ...      -0.023    2.184        0.248       -0.248
# 35112                0  ...      -0.023    2.171        0.220       -0.220
# 35113                0  ...      -0.023    2.171        0.220       -0.220
# 35114                0  ...      -0.023    2.171        0.220       -0.220
#
#        sy_gaiamag  sy_gaiamagerr1  sy_gaiamagerr2   rowupdate  pl_pubdate  \
# 0         4.44038        0.003848       -0.003848  2014-07-23     2011-08
# 1         4.44038        0.003848       -0.003848  2014-05-14     2008-01
# 2         4.44038        0.003848       -0.003848  2023-09-19     2023-08
# 3         4.56216        0.003903       -0.003903  2018-09-04     2017-03
# 4         4.56216        0.003903       -0.003903  2018-04-25     2011-08
# ...           ...             ...             ...         ...         ...
# 35110     3.98687        0.008937       -0.008937  2014-08-21     2004-01
# 35111     4.03040        0.008513       -0.008513  2022-01-10     2021-12
# 35112     4.42501        0.003837       -0.003837  2014-07-23     2011-08
# 35113     4.42501        0.003837       -0.003837  2014-05-14     2008-06
# 35114     4.42501        0.003837       -0.003837  2023-09-19     2023-08
#
#        releasedate
# 0       2014-07-23
# 1       2014-05-14
# 2       2023-09-19
# 3       2018-09-06
# 4       2014-07-23
# ...            ...
# 35110   2014-08-21
# 35111   2022-01-10
# 35112   2014-07-23
# 35113   2014-05-14
# 35114   2023-09-19
#
# [35115 rows x 92 columns]

# %%
# %pwd
# Out:
# 'C:\\Users\\Tom\\git\\notebooks'

# %%
# %cd ../../numerique/notebooks
# Out:
# [WinError 3] Le chemin d’accès spécifié est introuvable: '../../numerique/notebooks'
# C:\Users\Tom\git\notebooks
